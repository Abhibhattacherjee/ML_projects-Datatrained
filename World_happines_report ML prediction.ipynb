# %% [markdown]
# ### World Happiness  reports

# %% [markdown]
# ![1_RWR4s5t5h_ve0D4fy5-Z9w.jpeg](attachment:1_RWR4s5t5h_ve0D4fy5-Z9w.jpeg)

# %% [markdown]
# The World Happiness Report is a landmark survey of the state of global happiness. The first report was published in 2012, the second in 2013, the third in 2015, and the fourth in the 2016 Update. The World Happiness 2017, which ranks 155 countries by their happiness levels, was released at the United Nations at an event celebrating International Day of Happiness on March 20th. The report continues to gain global recognition as governments, organizations and civil society increasingly use happiness indicators to inform their policy-making decisions. Leading experts across fields – economics, psychology, survey analysis, national statistics, health, public policy and more –

# %% [markdown]
# The World Happiness Report is a publication of the Sustainable Development Solutions Network, powered by the Gallup World Poll data.

# %% [markdown]
# #### Importing libs

# %%
import pandas  as  pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
# loading  the  report  dataframe  with pandas 
df_rep= pd.read_csv('world_happiness_report..csv')
df_rep.head(10)
# Out:
#        Country                     Region  Happiness Rank  Happiness Score  \
# 0  Switzerland             Western Europe               1            7.587
# 1      Iceland             Western Europe               2            7.561
# 2      Denmark             Western Europe               3            7.527
# 3       Norway             Western Europe               4            7.522
# 4       Canada              North America               5            7.427
# 5      Finland             Western Europe               6            7.406
# 6  Netherlands             Western Europe               7            7.378
# 7       Sweden             Western Europe               8            7.364
# 8  New Zealand  Australia and New Zealand               9            7.286
# 9    Australia  Australia and New Zealand              10            7.284
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# ...

# %%
# checking   the  columns
df_rep.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# ### About All  the columns

# %% [markdown]
# 1.Country: This  column  shows  all  the  different  countries  which are  there  in  the  happiness  report  list.
#
# 2.Region :  It shows  how   different  regions   which  are  there  which basically  also tells  that  which country
#             falls   in  which regions
#
# 3.Happiness_Rank: This is  giving  us  the  idea  that  acccording   to  the  region and  country  which  country  has
#                   the  highest  ranking  in  happiness
#
# 4.Standard  error: The  standard  error  which  can be  taken  as  the  estimate  of  the  std  deviations which shows  us
#                    the  variance  or variability  in the , data report
#
# 5.Economy(GDP percapita): This  is  the  factor  which tells  us  about  the  country's  Gross  domestic  product.
#                            GDP is  the monetary value  of  the  products  which  are  made  inside  a country.
#
# 6.Family: This  is   the  column  which tells  us  about  the family  members happiness
#
# 7.Health (Life Expectancy):  this  column tells  us  about  how much  people  keep  them healthy  or  how much   people
#                              are  health concious  in diffrent  countries for  the  survival of long  life can be estimated
#
# 8.Freedom: - freedom  col  tells  us  that  how much  people   are  independent  about   doing  any  task in their
#                respective  lives as  lack  of  freedom may  slaught  down anyone's  happiness.
#
# 9.Trust (Government Corruption)	:  this  simply tell us  about  the political  parties  in that particular  country  which
#                                   are  doing  corruption  and  cutting  the  happiness means of people   for their  own
#                                   selish means
#
# 10.Generosity: This shows  that how much people  are  kind  for each other in a  country ex- helping
#
# 11.Dystopia Residual: -Dystopia is an imaginary country that has the world’s least-happy people. The purpose in establishing Dystopia is to have a benchmark against which all countries can be favorably compared

# %%
df_rep.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %% [markdown]
# so  we  can see  that  the  dataset has  no null values   in  it

# %% [markdown]
# ### Explolaratory Data Analysis on the  dataset

# %% [markdown]
# ###### Bivariate Analysis   on the  data cols

# %%
df_rep['Country'].value_counts()
# so there  are   total  158 countries
# Out:
# 135    1
# 10     1
# 51     1
# 77     1
# 57     1
#       ..
# 70     1
# 125    1
# 81     1
# 101    1
# 141    1
# Name: Country, Length: 158, dtype: int64

# %%
sns.distplot( df_rep['Happiness Rank'], bins=20)
# Out:
# <AxesSubplot:xlabel='Happiness Rank', ylabel='Density'>

# %% [markdown]
# This  shows  the  how  much density  of the  people have  touched  the  highest happines  rank

# %%
sns.violinplot( x="Happiness Score", data=df_rep)
# Out:
# <AxesSubplot:xlabel='Happiness Score'>

# %% [markdown]
# obsevations:  The  happiness score 5  is  most  frequent while
#
#                The  hapiness score 8 has  a medium frequency after 5
#
#                The  happiness score 2 & 3 is  very less  frequent   which is   good   for  the  world

# %%
sns.lmplot(x='Happiness Rank', y='Happiness Score',data= df_rep)

# %% [markdown]
# obsservation: as we  can see  that the  happiness scrore  is  increasing  the  happiness  ranks  also increased  to 160

# %%
sns.scatterplot(x ='Happiness Score',  y='Standard Error', data=df_rep, palette='deep', color='red')
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Standard Error'>

# %% [markdown]
# observations: As  the  Happiness  score  is increasing  there is  a increase  in the standard  error

# %%
sns.lmplot(x ='Happiness Score',  y='Economy (GDP per Capita)', data=df_rep, palette=dict)

# %% [markdown]
# observations : As  we  can see  that as  there  is  a positive increase in the Economy GDP the  happiness score is also
#                increasing  simultaneously

# %%
sns.regplot(x= 'Happiness Score', y ='Family', data =df_rep, robust=True)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Family'>

# %% [markdown]
# observations: as the  family  is increasing  the  happiness score  is  also  increasing

# %%
sns.scatterplot(x ='Happiness Score', y ='Health (Life Expectancy)', data=df_rep)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Health (Life Expectancy)'>

# %% [markdown]
# observations:

# %%
sns.regplot(x ='Happiness Score', y ='Freedom', data=df_rep)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Freedom'>

# %% [markdown]
# observations:

# %%
sns.regplot(x ='Happiness Score', y ='Trust (Government Corruption)', data=df_rep)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Trust (Government Corruption)'>

# %% [markdown]
# obsevations:

# %%
sns.violinplot( x="Generosity", data=df_rep, color ='red')
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %% [markdown]
# observations: Thus  it  shows   us  that very less frequency  has  the  geneoriisty or kindness near  too only  20%  people

# %%
sns.regplot(x ='Happiness Score', y ='Dystopia Residual', data =df_rep)
# Out:
# <AxesSubplot:xlabel='Happiness Score', ylabel='Dystopia Residual'>

# %% [markdown]
# #### Finding the  Correlation

# %%
df_rep.corr()
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.033879 -0.022600        0.158516
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
df_rep.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Region                          -0.176791
# Country                          0.083380
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %% [markdown]
# #### correlation heatmap

# %%
import matplotlib.pyplot  as plt
# making  the  canvas  size
plt.figure(figsize=(15,6))
sns.heatmap(df_rep.corr(),annot =True, linewidths=0.5, linecolor='black', fmt='.2f',cmap='plasma')
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Observations  done   from  Correlation

# %% [markdown]
# 1.  Happiness Rank  is  -ve 52%  correlated   to Happiness Score which  is  very bad
#
# 1.  Standard Error  is  8%  correlated   to Happiness Score which  is  bad
#
# 1.  Economy(GDP)  is  4%  correlated   to Happiness Score which is bad
#
# 1.  Family  is   15 % correlated   to Happiness Score is  good
#
# 1.  Health  is  2%  correlated   to Happiness Score whicvh is very bad
#
# 1.  Freedom is 6% correlated   to Happiness Score which is bad
#
# 1.  Trust(goct_curroption)  is -ve  3% correlated   to Happiness Score which is  very bad
#
# 1.  Geneoursly  is -ve 10% correlated   to Happiness Score which is  very bad
#
# 1.    Dystopia Residual  is  -ve 10%  correlated   to Happiness Score   which is  very bad

# %% [markdown]
# #### Describing  the data

# %%
df_rep.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %% [markdown]
# Thus  this  shows  the  statistical  summary of  the  dataset

# %% [markdown]
# ##### Heatmap  plottting

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df_rep.describe()[1:].transpose(),2), linewidth =2, fmt='f', annot=True,cmap='Blues')
plt.xticks(fontsize=18)
plt.yticks(fontsize=12)
plt.title('variable  summary')
plt.show()

# %% [markdown]
# Observations done:
#     Thus we  can see that  there  are  total  158 rows and 10  columns in the  dataset
#
#     1.Happiness Rank:
#         Mean: 79.49000
#         Std:45.75
#         min_value=1.000
#         max_value=118.7500
#
#     2.Standard_error:
#         Mean: 0.05000
#         std:  0.02000
#         min_value:0.02000
#         max_value:0.140000
#
#     3. Economy(GDP_percapita):
#         Mean: 0.85000
#         std: 0.400000
#         min_value:0.000
#         max_value:1.690000
#
#     4. family:
#         Mean:0.99000
#         std: 0.27000
#         min_value:0.000
#         max_value:1.400000
#
#     5. Health:
#         Mean:0.63
#         std:0.25000
#         min_value:0.0000
#         max_value:1.030000
#
#     6. Freedom:
#         Mean:0.43
#         std: 0.15
#         min_value:0.0000
#         max_value:0.67000
#
#     7. Trust(government  corruption):
#         Mean:0.14
#         std: 0.12
#         min_value:0.0000
#         max_value:0.55000
#
#     8. Generosity:
#         Mean:0.2400
#         std:0.13000
#         min_value:0.000
#         max_value:0.8000
#
#     9. Dystopia Residual:
#          Mean:2.10000
#          std:0.55000
#          min_value:0.33000
#          max_value:3.6000

# %%
df_rep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %% [markdown]
# By  the  above  code  stuff  we  get  know  the  datatype   in  the  dataset and  memory  usage  by it

# %% [markdown]
# #### Outliers Checking

# %%
sns.scatterplot(x='Happiness Rank',y='Standard Error', data =df_rep, markers=True, palette='Set3')
plt.xlabel('Happiness Rank')
plt.ylabel('Happiness score')
plt.show
#  so here  also  we  can check   the  outlier  far  than  the values
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# we can also  use   boxplot  to  for  better  results   to understand  the  outliers  present   in some 
#negative   cols 
sns.boxplot(df_rep. Family, orient='h')
# Out:
# <AxesSubplot:xlabel='Family'>

# %% [markdown]
# so  we  can see  that  family  has  also  some  outliers  present  in it

# %%
sns.scatterplot(x='Health (Life Expectancy)',y='Freedom', data =df_rep, markers=True,color='red')
plt.xlabel('Health (Life Expectancy)')
plt.ylabel('Freedom')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# Thus we  can see  that  there  are many  ouliers  present  in  the  columns

# %%
sns.boxplot(df_rep.Generosity)
# Out:
# <AxesSubplot:xlabel='Generosity'>

# %% [markdown]
# There  are  some very  few  outliers   present  in the columns of  genorisity

# %%
sns.boxplot(df_rep.Freedom, color='green')
# Out:
# <AxesSubplot:xlabel='Freedom'>

# %% [markdown]
# Thus  we can see  that  the column  Freedom  has  no  such  outliers

# %%
sns.scatterplot(x='Trust (Government Corruption)',y='Dystopia Residual', data =df_rep, palette='Set3', color='orange')
plt.xlabel('Trust (Government Corruption)')
plt.ylabel('Dystopia Residual')
plt.show()

# %% [markdown]
# Thus  there  is  some  outliers  even  prsent in  this   two columns    too

# %% [markdown]
# #### Checking  of the  skewness in  the  dataset
# Skewness is a measure of the asymmetry of a distribution. A distribution is asymmetrical when its left and right side are not mirror images.
#
# A distribution can have right (or positive), left (or negative), or zero skewness. A right-skewed distribution is longer on the right side of its peak, and a left-skewed distribution is longer on the left side of its peak:

# %%
df_rep.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# We have  to remove  the skewness   from  the  dataset as   it  will effect  our  machine  learning  model
# As
#
# Standard Error
#
# Family
#
# Trust
#
# Generosity
#
# has  the  max   of skewness which is above  the  threshold  valued=+/-0.65

# %% [markdown]
# ##### graph  representation of  the most highly  skewed data  columns

# %%
sns.distplot(df_rep['Standard Error'], vertical=False, color='red')
# Out:
# <AxesSubplot:xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# Thus  the  data  curve  here  is  not  in a normal distribution curve it is skewed to left

# %%
sns.distplot(df_rep['Family'], vertical=False, color='red')
# Out:
# <AxesSubplot:xlabel='Family', ylabel='Density'>

# %% [markdown]
# Thus  the  data  curve  here  is  not  in a normal distribution curve it is skewed to Right

# %%
sns.distplot(df_rep['Trust (Government Corruption)'], vertical=False, color='red')
# Out:
# <AxesSubplot:xlabel='Trust (Government Corruption)', ylabel='Density'>

# %% [markdown]
# Thus  the  data  curve  here  is  not  in a normal distribution curve it is skewed to left

# %%
sns.distplot(df_rep['Generosity'], vertical=False, color='red')
# Out:
# <AxesSubplot:xlabel='Generosity', ylabel='Density'>

# %% [markdown]
# Thus  the  data  curve  here  is  not  in a normal distribution curve it is skewed to left

# %% [markdown]
# The  Normalized  curved  shows  how  much  the  data  is  being skewed  or baised

# %% [markdown]
# ### Data Cleaning & preprocessing

# %%
df_rep.corr()['Happiness Score']
# Out:
# Country                          0.083380
# Region                          -0.176791
# Happiness Rank                  -0.992105
# Happiness Score                  1.000000
# Standard Error                  -0.177254
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Dystopia Residual                0.530474
# Name: Happiness Score, dtype: float64

# %% [markdown]
# So  as we can  check  that  the  column  standard  error  has both  hight
# skewness  value  of 1.98  &  even it  is  negative  contributing  very less  to  the  output  model
# so  we  can drop  the  feature  Standard  error  here
#
#
# As skewness  means  there  is  a  high possibility  of  Outliers in the  col

# %% [markdown]
# #### Dropping  the  -correlated  and  high skewed data col

# %%
df_rep.drop(['Standard Error'],axis=1, inplace=True )
df_rep.head()
# Out:
#    Country  Region  Happiness Rank  Happiness Score  Economy (GDP per Capita)  \
# 0      135       9               1            7.587                   1.39651
# 1       58       9               2            7.561                   1.30232
# 2       37       9               3            7.527                   1.32548
# 3      105       9               4            7.522                   1.45900
# 4       24       5               5            7.427                   1.32629
#
#     Family  Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0  1.34951                   0.94143  0.66557                        0.41978
# 1  1.40223                   0.94784  0.62877                        0.14145
# 2  1.36058                   0.87464  0.64938                        0.48357
# 3  1.33095                   0.88521  0.66973                        0.36503
# 4  1.32261                   0.90563  0.63297                        0.32957
#
#    Generosity  Dystopia Residual
# ...

# %% [markdown]
# thus  we  have  dropped  the  standard error  column

# %% [markdown]
# #####  Data has two categorical   values columns  so  we  have  encode   them

# %%
from sklearn.preprocessing  import LabelEncoder
le=LabelEncoder()
df_rep['Country']=le.fit_transform(df_rep['Country'])

# %%
df_rep['Region']=le.fit_transform(df_rep['Region'])

# %% [markdown]
# Thus  we  have  two  categorical  column  country and  region  which is  being encoded   here  for  getting  the zscore
# and   outliers present  in the dataset

# %% [markdown]
# ### Outliers removal  with   the  help  of  Scipy  Z-Score

# %%
import scipy 
from scipy.stats import zscore

# %% [markdown]
# The intution behind z -score  to describe  any data by  finding their  relationship , with  the sd and  the mean of the group
# of poinr plots .s score  if  for  finding thr distribution of  data  where , mean  is  0 and  the std  deviation is , 1.1
# normal dist.

# %%
z= np.abs(zscore(df_rep))
z
# Out:
#       Country    Region  Happiness Rank  Happiness Score  \
# 0    1.238770  1.300256        1.721000         1.937360
# 1    0.449465  1.300256        1.699075         1.914581
# 2    0.909893  1.300256        1.677149         1.884792
# 3    0.581016  1.300256        1.655224         1.880411
# 4    1.194920  0.040302        1.633299         1.797179
# ..        ...       ...             ...              ...
# 153  0.866043  0.965117        1.633576         1.674055
# 154  1.436096  0.965117        1.655501         1.783571
# 155  1.260695  0.375441        1.677427         2.076199
# 156  1.260695  0.965117        1.699352         2.164688
# 157  1.370321  0.965117        1.721277         2.222513
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# ...

# %%
#setting  the threshold   limit  as  3  accordance  to  the  emprical  rule  
threshold=3
print(np.where(z>3))
# Out:
# (array([ 27, 128, 147, 153, 155, 157], dtype=int64), array([ 8,  9,  5,  8, 10,  5], dtype=int64))

# %%
len(np.where(z>3)[0])
# Out:
# 6

# %%
z.iloc[155]
# Out:
# Country                          1.260695
# Region                           0.375441
# Happiness Rank                   1.677427
# Happiness Score                  2.076199
# Economy (GDP per Capita)         0.455245
# Family                           1.901086
# Health (Life Expectancy)         0.372199
# Freedom                          1.809238
# Trust (Government Corruption)    0.381419
# Generosity                       1.856891
# Dystopia Residual                3.208430
# Name: 155, dtype: float64

# %% [markdown]
# thus  by  changing  the  array index  here  we  can  know  that which  can column consists  of   outliers  as  155 row
#
#  has a  outlier  here in the Dystopia Residual col

# %%
# now  we  can  drop the  Outliers  from  the  rows 
df_new= df_rep[(z<3).all(axis=1)]
print('old_dataframe',df_rep.shape)
print('new_dataframe', df_new.shape)
print('total_dropped_rows', df_rep.shape[0]-df_new.shape[0])
# Out:
# old_dataframe (158, 11)
# new_dataframe (152, 11)
# total_dropped_rows 6

# %% [markdown]
# so now  all the  outliers are  being   removed

# %%
df_rep.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %% [markdown]
# #### Percentage  of Data  loss

# %%
loss_percentage = (158-152)/158*100
print(loss_percentage,'%')
# Out:
# 3.79746835443038 %

# %% [markdown]
# Dividing  the  feature  col and  the  output col

# %%
x=df_new.drop(['Happiness Score'],axis=1)
y = df_new.iloc[:,3]

# %% [markdown]
# #### Transforming  the Data  to remove skewness

# %%
from sklearn.preprocessing  import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[ 1.1887051 ,  1.23986819, -2.06118488, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819, -2.00536253, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819, -1.95460445, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186,  1.5407485 , ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613,  1.57594638, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613,  1.61101853, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %%
pd.DataFrame(x).skew()
# Out:
# 0   -0.267218
# 1   -0.216720
# 2   -0.261914
# 3   -0.144167
# 4   -0.149268
# 5   -0.184207
# 6   -0.077878
# 7    0.179115
# 8    0.022444
# 9    0.014422
# dtype: float64

# %% [markdown]
# plotting  the  normal dis  columns

# %%
sns.distplot(X[4], color='green')
plt.title("Family")
plt.show()

# %% [markdown]
# so  we  can see that  Family  is  now normally distributed

# %%
sns.distplot(X[8], color='green')
plt.title("Generosity")
plt.show()

# %% [markdown]
# so  here the  Generosity column was  highly skewed  which being  transformed

# %%
sns.distplot(X[7], color='green')
plt.title('Trust (Government Corruption)')
plt.show()

# %% [markdown]
# as Trust (Government Corruption)  column was highly skewed  data  so  it  is also  being  transformed

# %% [markdown]
# #### Feature - Scaling  with Standardization

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc.fit_transform(x)
x
# Out:
# array([[ 1.1887051 ,  1.23986819, -2.06118488, ...,  1.8220699 ,
#          0.65595135,  0.74453432],
#        [-0.31421047,  1.23986819, -2.00536253, ...,  0.35523024,
#          1.57166845,  1.10426166],
#        [-0.81704158,  1.23986819, -1.95460445, ...,  1.95457489,
#          0.97742359,  0.69531125],
#        ...,
#        [-2.10859031,  0.67236186,  1.5407485 , ..., -0.16357633,
#          1.13659521, -0.34441601],
#        [-1.51998719,  0.96090613,  1.57594638, ..., -0.40394411,
#         -0.32359556, -0.94945138],
#        [-1.26108344,  0.96090613,  1.61101853, ..., -0.11827784,
#         -0.18319784, -0.57122297]])

# %% [markdown]
# So  now  we  have performed   the  standard  scaling in all  of  our  features for  making a best   model  from the
# data
#
# standarization means
#
# mean : 0
#
# std.dev=1

# %% [markdown]
# ### Creating a Best Fit ML model for prediction

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.ensemble import AdaBoostRegressor

# %% [markdown]
# #### Splitting  the Dataframe

# %% [markdown]
# ###### creating  & Training  the model

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y, random_state=49, test_size=0.20)
lr= LinearRegression()
lr.fit(x_train,y_train)
pred=lr.predict(x_test)
print('Result  from Linear regression model')
print('R2 score is ',r2_score(pred_test,y_test))
print('mean_squared_error', mean_squared_error(pred_test,y_test))
# Out:
# Result  from Linear regression model
# R2 score is  0.9973801392815617
# mean_squared_error 0.0034275860394540098

# %%
x_train.shape
# Out:
# (121, 10)

# %%
x_test.shape
# Out:
# (31, 10)

# %%
y_train.shape
# Out:
# (121,)

# %%
y_test.shape
# Out:
# (31,)

# %% [markdown]
# Thus we have  got  our accuracy score  of  model very  good  as 0.99

# %%
rf=RandomForestRegressor(n_estimators=1000)
rf.fit(x_train,y_train)
pred=rf.predict(x_test)
print('result  from random_forestregressor')
print('R2 score is ',r2_score(pred_test,y_test))
print('mean_squared_error', mean_squared_error(pred_test,y_test))
# Out:
# result  from random_forestregressor
# R2 score is  0.9973801392815617
# mean_squared_error 0.0034275860394540098

# %%
ab = AdaBoostRegressor()
ab.fit(x_train,y_train)
pred=ab.predict(x_test)
print('result  from AdaBoostregressor')
print('R2 score is ',r2_score(pred_test,y_test))
print('mean_squared_error', mean_squared_error(pred_test,y_test))
# Out:
# result  from AdaBoostregressor
# R2 score is  0.9973801392815617
# mean_squared_error 0.0034275860394540098

# %% [markdown]
# #### Model_scores of Linear_reg,Random_forest, Adaboost-regressor

# %%
reg=lr.score(x_train, y_train)
rand=rf.score(x_train,y_train)
ada=ab.score(x_train,y_train)
print(reg)

print(rand)

print(ada)
# Out:
# 0.9957646902096267
# 0.999375319735982
# 0.9982080173608617

# %% [markdown]
# So as we  can see  that  all  the  three  algorithms  are  giving  us  the almost same model accuracy  score  thus
# we  can easily  go   with  any  of  the  model   for  our prediction but  in that  case random forest doing  quite
# good  than others   which is 0.99375

# %% [markdown]
# ### Using the simple- tuning  techniques

# %% [markdown]
# we  can  tune   the  model as  being  model accuracy as  99%  but still  there  is  much chance  that
# it might  have  over-fitting

# %% [markdown]
# ###### using of K-Fold cross-validation technique

# %%
pred_rf= rf.predict(x_test)
from sklearn.model_selection import cross_val_score
lrf= r2_score(y_test,pred_rf)
for j in range(2,10):
    lrfscore=cross_val_score(rf,x,y,cv=j)
    lrfs= lrfscore.mean()
    print('At cv:',j)
    print('cross_validation_score is:',lrfs*100)
    print('R2_score is :',lrf*100)
    print("\n")
# Out:
# At cv: 2
# cross_validation_score is: -281.6259232148815
# R2_score is : 99.86292636213886
#
#
# At cv: 3
# cross_validation_score is: -158.0205004440736
# R2_score is : 99.86292636213886
#
#
# At cv: 4
# cross_validation_score is: -212.87947342941402
# R2_score is : 99.86292636213886
#
#
# At cv: 5
# cross_validation_score is: -167.98326986959097
# R2_score is : 99.86292636213886
#
#
# At cv: 6
# cross_validation_score is: -165.75419351955264
# R2_score is : 99.86292636213886
#
#
# At cv: 7
# cross_validation_score is: -226.72355009648408
# R2_score is : 99.86292636213886
#
#
# At cv: 8
# cross_validation_score is: -194.85335980706776
# R2_score is : 99.86292636213886
#
#
# At cv: 9
# cross_validation_score is: -181.4879533525409
# R2_score is : 99.86292636213886

# %% [markdown]
# ###### so we used Random forest as  our main model as it  work  better  than  others

# %% [markdown]
# ##### selection   of  validation score from CV

# %%
lrfscore_selected=cross_val_score(rf,x,y,cv=5).mean()
print("cv score  is:",lrfscore_selected,"\n accuracy_score is:",lrfs)
#so we have  selected  the  cv=5 which is  working  good
# Out:
# cv score  is: -1.6820087335182898
#  accuracy_score is: -1.8148795335254089

# %% [markdown]
# #### Saving the  model using Pickle

# %%
import pickle
filename='world_happines_report'
pickle.dump(rf,open(filename,'wb'))

# %% [markdown]
# #### Working ML model  for prediction

# %%
import numpy as np
a =np.array(y_test)
predicted=np.array(rf.predict(x_test))
df_com=pd.DataFrame({'Orginal':a,'Predicted':predicted}, index=range(len(a)))
df_com
# Out:
#     Orginal  Predicted
# 0     4.677   4.662777
# 1     3.819   3.785765
# 2     5.848   5.846136
# 3     5.192   5.202879
# 4     5.268   5.241667
# 5     5.129   5.150559
# 6     3.904   3.889503
# 7     4.297   4.249273
# 8     5.098   5.079669
# 9     5.073   5.045040
# 10    4.633   4.599146
# 11    4.800   4.801061
# 12    6.505   6.501444
# 13    4.436   4.421534
# 14    7.527   7.459994
# 15    4.715   4.711037
# 16    4.350   4.319471
# 17    4.252   4.220664
# 18    3.781   3.723768
# 19    3.995   3.954551
# 20    4.681   4.681798
# 21    6.940   6.921123
# 22    6.901   6.857256
# 23    6.798   6.811680
# 24    5.102   5.131493
# 25    7.561   7.444594
# 26    3.667   3.560683
# 27    5.975   5.959796
# 28    4.507   4.497191
# 29    6.937   6.862345
# 30    5.474   5.440314

# %% [markdown]
# so we  can  see that the  prediction of  the  model  very  much accurate

# %% [markdown]
# ##### Thus further  the  model is  ready  for  the deployment in cloud or any production server

# %%
model = df_com.to_excel('happiness_report.xlsx')
model
